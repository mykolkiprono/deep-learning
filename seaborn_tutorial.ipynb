# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

# %matplotlib inline

# %%
X, y = load_iris(return_X_y = True, as_frame = True)

# %%
# print(sns.get_dataset_names())

# %%
# df = sns.load_dataset('car_crashes')

# %% [markdown]
# ### distribution plot

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
sns.displot(X['sepal length (cm)'], kde = True, bins = 25, color = 'green', legend = True) # distribution of one variable

# %% [markdown]
# ### joint plot ; used to compare two distributions

# %%
sns.jointplot(x = 'petal length (cm)', y = 'sepal length (cm)', data = X, kind = 'kde')

# %%
sns.kdeplot(X['petal length (cm)'])
# Out:
# <AxesSubplot:xlabel='petal length (cm)', ylabel='Density'>

# %% [markdown]
# ### pair plot

# %%
sns.pairplot(X) #sns.pairplot(X, hue = '', pallete = 'Blues')

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### rug plot

# %%
sns.rugplot(X['petal width (cm)'])
# Out:
# <AxesSubplot:xlabel='petal width (cm)'>

# %% [markdown]
# ### styling

# %%
sns.set_style('white')
sns.set_context('paper', font_scale = 1.4)

# %%
plt.figure(figsize = (10,7))
sns.jointplot(x = 'petal width (cm)', y = 'petal length (cm)', data = X, kind = 'reg')
sns.despine(left = False)

# %%
sns.set_style('dark')
sns.displot(X['petal length (cm)'], bins = 100)

# %% [markdown]
# ### categorical plots

# %% [markdown]
# #### bar plots

# %%
datatype = {'fbs':'category', 'sex':'category', 'slope':'category', 'cp':'category'}

# %%
heart = pd.read_csv("/home/mikey/Downloads/csv_datasets/archive(8)/heart.csv", dtype = datatype)

# %%
heart.head()
# Out:
#    age sex cp  trestbps  chol fbs  restecg  thalach  exang  oldpeak slope  ca  \
# 0   63   1  3       145   233   1        0      150      0      2.3     0   0
# 1   37   1  2       130   250   0        1      187      0      3.5     0   0
# 2   41   0  1       130   204   0        0      172      0      1.4     2   0
# 3   56   1  1       120   236   0        1      178      0      0.8     2   0
# 4   57   0  0       120   354   0        1      163      1      0.6     2   0
#
#    thal  target
# 0     1       1
# 1     2       1
# 2     2       1
# 3     2       1
# 4     2       1

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    category
#  2   cp        303 non-null    category
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    category
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    category
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: category(4), float64(1), int64(9)
# memory usage: 25.6 KB

# %%
sns.pairplot(heart, hue = 'sex')

# %%
import numpy as np

# %%
sns.barplot(x = 'cp', y = 'age', data = heart, estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %% [markdown]
# ### count plot

# %%
sns.countplot(x = 'cp', data = heart)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %% [markdown]
# ### box plot

# %%
heart.head()
# Out:
#    age sex cp  trestbps  chol fbs  restecg  thalach  exang  oldpeak slope  ca  \
# 0   63   1  3       145   233   1        0      150      0      2.3     0   0
# 1   37   1  2       130   250   0        1      187      0      3.5     0   0
# 2   41   0  1       130   204   0        0      172      0      1.4     2   0
# 3   56   1  1       120   236   0        1      178      0      0.8     2   0
# 4   57   0  0       120   354   0        1      163      1      0.6     2   0
#
#    thal  target
# 0     1       1
# 1     2       1
# 2     2       1
# 3     2       1
# 4     2       1

# %%
sns.boxplot(x = 'cp', y = 'age', data = heart, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %% [markdown]
# ### violin plot

# %%
sns.violinplot(x = 'cp', y = 'age', data = heart, hue = 'sex', split = True)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %% [markdown]
# ### strpiplot

# %%
plt.figure(figsize=(10,7))

sns.stripplot(x = 'cp', y = 'age', data = heart, hue = 'sex', jitter = True, dodge = True)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %%
sns.violinplot(x = 'cp', y = 'age', data = heart)
sns.swarmplot(x = 'cp', y = 'age', data = heart, color = 'white')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %%
sns.swarmplot(x = 'cp', y = 'age', data = heart)
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %%
plt.figure(figsize=(10,7))
sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(x = 'cp', y = 'age', data = heart, hue = 'sex', palette = 'magma')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='age'>

# %% [markdown]
# ### matrix plot

# %% [markdown]
# ### heatmap

# %%
plt.figure(figsize=(10,8))
sns.set_context('paper', font_scale = 1.4)

cor = X.corr()
sns.heatmap(cor, annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
p = heart.groupby('cp')

# %%
p.count()
# Out:
#     age  sex  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# cp
# 0   143  143       143   143  143      143      143    143      143    143
# 1    50   50        50    50   50       50       50     50       50     50
# 2    87   87        87    87   87       87       87     87       87     87
# 3    23   23        23    23   23       23       23     23       23     23
#
#      ca  thal  target
# cp
# 0   143   143     143
# 1    50    50      50
# 2    87    87      87
# 3    23    23      23

# %%
p.mean()
# Out:
#           age    trestbps        chol   restecg     thalach     exang  \
# cp
# 0   55.692308  132.020979  250.132867  0.475524  140.538462  0.559441
# 1   51.360000  128.400000  244.780000  0.620000  162.420000  0.080000
# 2   53.517241  130.379310  243.172414  0.597701  155.609195  0.126437
# 3   55.869565  140.869565  237.130435  0.391304  155.956522  0.173913
#
#      oldpeak        ca      thal    target
# cp
# 0   1.383217  0.965035  2.447552  0.272727
# 1   0.316000  0.420000  2.140000  0.820000
# 2   0.797701  0.586207  2.206897  0.793103
# 3   1.391304  0.478261  2.260870  0.695652

# %%
heart.head()
# Out:
#    age sex cp  trestbps  chol fbs  restecg  thalach  exang  oldpeak slope  ca  \
# 0   63   1  3       145   233   1        0      150      0      2.3     0   0
# 1   37   1  2       130   250   0        1      187      0      3.5     0   0
# 2   41   0  1       130   204   0        0      172      0      1.4     2   0
# 3   56   1  1       120   236   0        1      178      0      0.8     2   0
# 4   57   0  0       120   354   0        1      163      1      0.6     2   0
#
#    thal  target
# 0     1       1
# 1     2       1
# 2     2       1
# 3     2       1
# 4     2       1

# %%
heart.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
p = heart.pivot_table(index = 'oldpeak', columns = 'cp',values = 'age')

# %%
p.isnull().sum()
# Out:
# cp
# 0     6
# 1    27
# 2    15
# 3    25
# dtype: int64

# %%
p.dropna(inplace = True)

# %%
p.isnull().sum()
# Out:
# cp
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
p.head()
# Out:
# cp           0          1          2          3
# oldpeak
# 0.0      52.25  49.903226  50.333333  48.333333
# 0.2      58.25  58.000000  53.000000  59.000000
# 0.6      55.80  47.000000  51.666667  64.000000
# 0.8      53.00  54.000000  58.833333  50.500000
# 1.0      58.40  48.000000  64.500000  58.000000

# %%
p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 8 entries, 0.0 to 1.8
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       8 non-null      float64
#  1   1       8 non-null      float64
#  2   2       8 non-null      float64
#  3   3       8 non-null      float64
# dtypes: float64(4)
# memory usage: 320.0 bytes

# %%
p
# Out:
# cp               0          1          2          3
# oldpeak
# 0.0      52.250000  49.903226  50.333333  48.333333
# 0.2      58.250000  58.000000  53.000000  59.000000
# 0.6      55.800000  47.000000  51.666667  64.000000
# 0.8      53.000000  54.000000  58.833333  50.500000
# 1.0      58.400000  48.000000  64.500000  58.000000
# 1.2      53.909091  55.000000  55.333333  48.500000
# 1.4      55.666667  52.666667  46.000000  52.000000
# 1.8      55.200000  58.000000  63.000000  66.500000

# %%
sns.heatmap(p, annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='oldpeak'>

# %% [markdown]
#  ### custermap

# %%
sns.clustermap(X)

# %% [markdown]
# ### pairgrids

# %%
X, y = load_iris(return_X_y=True, as_frame = True)

# %%
iris_grid = sns.PairGrid(X)
iris_grid.map(plt.scatter)
iris_grid.map_diag(plt.hist)
iris_grid.map_offdiag(plt.scatter)
iris_grid.map_lower(sns.kdeplot)

# iris_g = sns.PairGrid(X, hue = 'species', 
#                      x_vars = ['sepal_width', 'sepal_lenght'],
#                      y_vars = ['petal_width', 'petal_legth'])

# %% [markdown]
# ### FacetGrid

# %%
x_grid = sns.FacetGrid(X, col = 'sepal length (cm)', row = 'petal length (cm)')
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/mikey/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-203-99054a27ee4f>", line 1, in <module>
#     x_grid = sns.FacetGrid(X, col = 'sepal length (cm)', row = 'petal length (cm)')
#   File "/home/mikey/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py", line 46, in inner_f
#     return f(**kwargs)
#   File "/home/mikey/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py", line 460, in __init__
#     self.tight_layout()
#   File "/home/mikey/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py", line 64, in tight_layout
#     self.fig.tight_layout(*args, **kwargs)
#   File "/home/mikey/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/deprecation.py", line 411, in wrapper
# ...

# %%
 X.head()
