# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import r2_score

# %%
x=np.random.uniform(5,15,15)
y=np.random.uniform(80,100,15)
plt.scatter(x,y)
plt.show()

# %%
x=[5,7,8,7,2,17,2,9,4,11,12,9,6]
y=[99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
plt.show()

# %%
slope,intercept,r,p,std_err= stats.linregress(x,y)
def myfunc(x):
    return slope*x+intercept
mymodel=list(map(myfunc,x))
plt.scatter(x,y)
plt.plot(x,mymodel)
plt.show()

# %%
r
# Out:
# -0.7585915243761551

# %%
# slope,intercept,r,p,std_err= stats.linregress(w,z)
def myfunc(w):
    return slope*w+intercept
mymodel=list(map(myfunc,w))
plt.scatter(w,z)
plt.plot(w,mymodel)
plt.show()

# %%
new=myfunc(13)
new
# Out:
# 80.3392200147167

# %%
r
# Out:
# -0.7585915243761551

# %% [markdown]
# ## polynomial regression

# %%
x=[1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y=[100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
plt.scatter(x,y)
plt.show()

# %%
mymodel=np.poly1d(np.polyfit(x,y,3))
myline=np.linspace(1,22,100) #method of creating a polynomial regression
plt.scatter(x,y)
plt.plot(myline,mymodel(myline))
plt.show()

# %%
print(r2_score(y,mymodel(x)))
# Out:
# 0.9432150416451026
