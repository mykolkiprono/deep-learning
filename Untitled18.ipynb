# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,BatchNormalization,Activation,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
# from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import warnings
import numpy as np
import shutil
import itertools
import glob
import random
warnings.simplefilter(action = 'ignore',category = FutureWarning)
# %matplotlib inline

# %%
os.chdir('/home/mikey/Downloads/flowers')
# if os.path.isdir('train/tulip') is False:
#     os.makedirs('train/dandelion')    
#     os.makedirs('train/rose')
#     os.makedirs('train/sunflower')
#     os.makedirs('train/daisy')
    
#     os.makedirs('test/tulip')
#     os.makedirs('test/dandelion')    
#     os.makedirs('test/rose')
#     os.makedirs('test/sunflower')
#     os.makedirs('test/daisy')
    
#     os.makedirs('valid/tulip')
#     os.makedirs('valid/dandelion')    
#     os.makedirs('valid/rose')
#     os.makedirs('valid/sunflower')
#     os.makedirs('valid/daisy') 
os.chdir('/home/mikey/Downloads/flowers/rose')
for c in random.sample(glob.glob('*.jpg'),250):
    os.chdir('/home/mikey/Downloads/flowers/train/rose')
    shutil.move(c,'rose')
    
for c in random.sample(glob.glob('*.jpg'),250):
    os.chdir('/home/mikey/Downloads/flowers/dandelion')
    shutil.move(c,'train/dandelion')
        
for c in random.sample(glob.glob('*.jpg'),250):
    os.chdir('/home/mikey/Downloads/flowers/sunflower')
    shutil.move(c,'train/sunflower')
        
for c in random.sample(glob.glob('.jpg'),250):
    os.chdir('/home/mikey/Downloads/daisy')
    shutil.move(c,'train/daisy')
        
for c in random.sample(glob.glob('.jpg'),250):
    os.chdir('/home/mikey/Downloads/flowers/tulip')
    shutil.move(c,'tulip/tulip')

#     TEST
for c in random.sample(glob.glob('.jpg'),50):
    os.chdir('/home/mikey/Downloads/flowers/sunflower')
    shutil.move(c,'test/sunflower')
    
for c in random.sample(glob.glob('.jpg'),50):
    os.chdir('/home/mikey/Downloads/flowers/tulip')
    shutil.move(c,'test/tulip')
    
for c in random.sample(glob.glob('.jpg'),50):
    os.chdir('/home/mikey/Downloads/flowers/daisy')
    shutil.move(c,'test/daisy')
    
for c in random.sample(glob.glob('.jpg'),50):
    os.chdir('/home/mikey/Downloads/flowers/dandelion')
    shutil.move(c,'test/dandelion')
    
for c in random.sample(glob.glob('.jpg'),50):
    os.chdir('/home/mikey/Downloads/flowers/rose')
    shutil.move(c,'test/rose')
    
# VALID
for c in random.sample(glob.glob('.jpg'),50):
    
    shutil.move(c,'valid/sunflower')
    
for c in random.sample(glob.glob('.jpg'),50):
    shutil.move(c,'valid/dandelion')
    
for c in random.sample(glob.glob('.jpg'),50):
    shutil.move(c,'valid/daisy')
    
for c in random.sample(glob.glob('.jpg'),50):
    shutil.move(c,'test/tulip')
    
for c in random.sample(glob.glob('.jpg'),50):
    shutil.move(c,'test/rose')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/envs/tensorflow/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     565     try:
# --> 566         os.rename(src, real_dst)
#     567     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '6409000675_6eb6806e59.jpg' -> 'rose'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-1b72a2edb1b6> in <module>
#      20 for c in random.sample(glob.glob('*.jpg'),250):
#      21     os.chdir('/home/mikey/Downloads/flowers/train/rose')
# ---> 22     shutil.move(c,'rose')
#      23
#      24 for c in random.sample(glob.glob('*.jpg'),250):
#
# ~/anaconda3/envs/tensorflow/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     578             rmtree(src)
# ...

# %%
os.chdir('/home/mikey/Downloads/flowers')
